# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('induce-data-2019-08-08.csv').iloc[:, :]

# %% [markdown]
# ### Question distribution over the parts

# %%
question_type = data.loc[:,'type']

# %%
question_type.hist(weights = np.ones_like(question_type.index) / len(question_type.index))
plt.show()

# %% [markdown]
# ### Percentage of correct / wrong result for INTRO

# %%
question_type_result = data.loc[:, ('type', 'result')]
question_intro = question_type_result[question_type_result.type == 'INTRO']

# %%
question_intro.loc[:,'result'].hist(weights = np.ones_like(question_intro.index) / len(question_intro.index))

# %% [markdown]
# ### Result distribution for DUAL questions

# %%
question_feature_result = data.loc[:, ('feature', 'result')]
question_dual_result = question_feature_result[question_feature_result.feature == 'dual'].loc[:, 'result']

# %%
question_dual_result.hist(weights = np.ones_like(question_dual_result.index)/len(question_dual_result.index))
